# %%
import numpy as np
from numpy.random import randn
N = 1000
counter = 0
for x in randn(N):    
    if(x > -1 and x < 1):
        counter = counter + 1
        print("randn of", N, "is:", x, "which is > -1 and < 1. counter is:", counter)
        
print("--------------------------------------------------------------------------------")
print("Counter is:", counter)
print("N is:", N)
print("Result is (counter/N):", counter / N)
# Out:
# randn of 1000 is: 0.557963406048 which is > -1 and < 1. counter is: 1
# randn of 1000 is: 0.0507823851829 which is > -1 and < 1. counter is: 2
# randn of 1000 is: -0.72138033379 which is > -1 and < 1. counter is: 3
# randn of 1000 is: 0.0986236666325 which is > -1 and < 1. counter is: 4
# randn of 1000 is: -0.0627145477181 which is > -1 and < 1. counter is: 5
# randn of 1000 is: 0.117253162384 which is > -1 and < 1. counter is: 6
# randn of 1000 is: 0.807731012418 which is > -1 and < 1. counter is: 7
# randn of 1000 is: -0.13450628002 which is > -1 and < 1. counter is: 8
# randn of 1000 is: 0.209552565858 which is > -1 and < 1. counter is: 9
# randn of 1000 is: -0.109759416867 which is > -1 and < 1. counter is: 10
# randn of 1000 is: 0.462837619367 which is > -1 and < 1. counter is: 11
# randn of 1000 is: -0.064181616603 which is > -1 and < 1. counter is: 12
# randn of 1000 is: -0.870894113201 which is > -1 and < 1. counter is: 13
# ...
