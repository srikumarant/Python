# %%
import pandas as pd
import os

# %%
#Import Data
stats1 = pd.read_csv('S:\\Study\\Data Science\\Udemy\\Python\\Projects\\Data Frames\\DemographicData.csv')
stats1.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,4
import warnings
warnings.filterwarnings('ignore')

# %%
#Seaborn Distribution
vis1 = sns.distplot(stats1["Internet users"], bins = 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0a08061b985d> in <module>()
#       1 #Seaborn Distribution
# ----> 2 vis1 = sns.distplot(stats1["Internet users"], bins = 30)
#
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     222     if kde:
#     223         kde_color = kde_kws.pop("color", color)
# --> 224         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     225         if kde_color != color:
#     226             kde_kws["color"] = kde_color
#
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
# ...

# %%
#Seaborn Boxplot
vis2 = sns.boxplot(data = stats1, x = "Income Group", y = "Birth rate")

# %%
vis3 = sns.lmplot(data=stats1, x='Internet users', y='Birth rate', fit_reg=False, \
                 hue="Income Group", size=7, scatter_kws={"s":100}, aspect=1)
